# %% [markdown]
# # DNN Premier League Football Predict

# %% [markdown]
# ### Import the pertinent libraries

# %%
import pandas as pd

import tensorflow as tf

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %% [markdown]
# ## Data

# %% [markdown]
# # http://www.football-data.co.uk/brazil.php Data
#
# ## Data Description
#
# ### Notes for Football Data
#
# All data is in csv format, ready for use within standard spreadsheet applications. Please note that some abbreviations are no longer in use (in particular odds from specific bookmakers no longer used) and refer to data collected in earlier seasons. For a current list of what bookmakers are included in the dataset please visit http://www.football-data.co.uk/matches.php
#
# #### Key to results data:
#
# - Div = League Division
# - Date = Match Date (dd/mm/yy)
# - HomeTeam = Home Team
# - AwayTeam = Away Team
# - FTHG = Full Time Home Team Goals
# - FTAG = Full Time Away Team Goals
# - FTR = Full Time Result (H=Home Win, D=Draw, A=Away Win)
# - HTHG = Half Time Home Team Goals
# - HTAG = Half Time Away Team Goals
# - HTR = Half Time Result (H=Home Win, D=Draw, A=Away Win)
#
# #### Match Statistics (where available)
# - Referee = Match Referee
# - HS = Home Team Shots
# - AS = Away Team Shots
# - HST = Home Team Shots on Target
# - AST = Away Team Shots on Target
# - HC = Home Team Corners
# - AC = Away Team Corners
# - HF = Home Team Fouls Committed
# - AF = Away Team Fouls Committed
# - HO = Home Team Offsides
# - AO = Away Team Offsides
# - HY = Home Team Yellow Cards
# - AY = Away Team Yellow Cards
# - HR = Home Team Red Cards
# - AR = Away Team Red Cards
#
# Note also that English and Scottish yellow cards do not include the initial yellow card when a second is shown to a player converting it into a red, but this is included as a yellow (plus red) for European games.
#
# ##### Key to 1X2 (match) betting odds data:
#
# - B365H = Bet365 home win odds
# - B365D = Bet365 draw odds
# - B365A = Bet365 away win odds
# - BWH = Bet&Win home win odds
# - BWD = Bet&Win draw odds
# - BWA = Bet&Win away win odds
# - IWH = Interwetten home win odds
# - IWD = Interwetten draw odds
# - IWA = Interwetten away win odds
# - LBH = Ladbrokes home win odds
# - LBD = Ladbrokes draw odds
# - LBA = Ladbrokes away win odds
# - WHH = William Hill home win odds
# - WHD = William Hill draw odds
# - WHA = William Hill away win odds
# - VCH = VC Bet home win odds
# - VCD = VC Bet draw odds
# - VCA = VC Bet away win odds
#
# - Bb1X2 = Number of BetBrain bookmakers used to calculate match odds averages and maximums
# - BbMxH = Betbrain maximum home win odds
# - BbAvH = Betbrain average home win odds
# - BbMxD = Betbrain maximum draw odds
# - BbAvD = Betbrain average draw win odds
# - BbMxA = Betbrain maximum away win odds
# - BbAvA = Betbrain average away win odds
#
# #### Key to total goals betting odds:
#
# - BbOU = Number of BetBrain bookmakers used to calculate over/under 2.5 goals (total goals) averages and maximums
# - BbMx>2.5 = Betbrain maximum over 2.5 goals
# - BbAv>2.5 = Betbrain average over 2.5 goals
# - BbMx<2.5 = Betbrain maximum under 2.5 goals
# - BbAv<2.5 = Betbrain average under 2.5 goals
#
# #### Key to Asian handicap betting odds:
#
# - BbAH = Number of BetBrain bookmakers used to Asian handicap averages and maximums
# - BbAHh = Betbrain size of handicap (home team)
# - BbMxAHH = Betbrain maximum Asian handicap home team odds
# - BbAvAHH = Betbrain average Asian handicap home team odds
# - BbMxAHA = Betbrain maximum Asian handicap away team odds
# - BbAvAHA = Betbrain average Asian handicap away team odds
#
# Football-Data would like to acknowledge the following sources which have been utilised in the compilation of Football-Data's results and odds files.
#
#
# Current results (full time, half time)
# Xcores - http://www.xcores .com
#
# Match statistics
# Sportinglife, ESPN Soccer, Bundesliga.de, Gazzetta.it and Football.fr
#
# Bookmakers betting odds
# Betbrain - http://www.betbrain.com
# Oddsportal - http://www.oddsportal.com
# Individual bookmakers
#
# Betting odds for weekend games are collected Friday afternoons, and on Tuesday afternoons for midweek games.

# %%
import os
os.listdir('../Data/Premier_League/')
# Out:
# ['0405.csv',
#  '0506.csv',
#  '0607.csv',
#  '0708.csv',
#  '0809.csv',
#  '0910.csv',
#  '1011.csv',
#  '1112.csv',
#  '1213.csv',
#  '1314.csv',
#  '1415.csv',
#  '1516.csv',
#  '1617.csv',
#  '1718.csv',
#  '1818.csv']

# %%
import glob
glob.glob('../Data/Premier_League/*.csv')
# Out:
# ['../Data/Premier_League\\0405.csv',
#  '../Data/Premier_League\\0506.csv',
#  '../Data/Premier_League\\0607.csv',
#  '../Data/Premier_League\\0708.csv',
#  '../Data/Premier_League\\0809.csv',
#  '../Data/Premier_League\\0910.csv',
#  '../Data/Premier_League\\1011.csv',
#  '../Data/Premier_League\\1112.csv',
#  '../Data/Premier_League\\1213.csv',
#  '../Data/Premier_League\\1314.csv',
#  '../Data/Premier_League\\1415.csv',
#  '../Data/Premier_League\\1516.csv',
#  '../Data/Premier_League\\1617.csv',
#  '../Data/Premier_League\\1718.csv',
#  '../Data/Premier_League\\1818.csv']

# %%
import pandas as pd
#df04_05 = pd.read_csv('../Data/Premier_League\\0405.csv', error_bad_lines=False)
df05_06 = pd.read_csv('../Data/Premier_League\\0506.csv', error_bad_lines=False)
df06_07 = pd.read_csv('../Data/Premier_League\\0607.csv', error_bad_lines=False)
df07_08 = pd.read_csv('../Data/Premier_League\\0708.csv', error_bad_lines=False)
df08_09 = pd.read_csv('../Data/Premier_League\\0809.csv', error_bad_lines=False)
df09_10 = pd.read_csv('../Data/Premier_League\\0910.csv', error_bad_lines=False)
df10_11 = pd.read_csv('../Data/Premier_League\\1011.csv', error_bad_lines=False)
df11_12 = pd.read_csv('../Data/Premier_League\\1112.csv', error_bad_lines=False)
df12_13 = pd.read_csv('../Data/Premier_League\\1213.csv', error_bad_lines=False)
df13_14 = pd.read_csv('../Data/Premier_League\\1314.csv', error_bad_lines=False)
df14_15 = pd.read_csv('../Data/Premier_League\\1415.csv', error_bad_lines=False)
df15_16 = pd.read_csv('../Data/Premier_League\\1516.csv', error_bad_lines=False)
df16_17 = pd.read_csv('../Data/Premier_League\\1617.csv', error_bad_lines=False)
df17_18 = pd.read_csv('../Data/Premier_League\\1718.csv', error_bad_lines=False)
df18_18 = pd.read_csv('../Data/Premier_League\\1818.csv', error_bad_lines=False)

# %%
df05_06.drop(['GBH','GBD','GBA','SJH','SJD','SJA','SBH','SBD','SBA'], inplace=True, axis=1)
df06_07.drop(['GBH','GBD','GBA','SJH','SJD','SJA','SBH','SBD','SBA'], inplace=True, axis=1)
df07_08.drop(['GBH','GBD','GBA','SJH','SJD','SJA','BSH','BSD','BSA','SBH','SBD','SBA'], inplace=True, axis=1)
df08_09.drop(['GBH','GBD','GBA','SJH','SJD','SJA','BSH','BSD','BSA','SBH','SBD','SBA'], inplace=True, axis=1)
df09_10.drop(['GBH','GBD','GBA','SJH','SJD','SJA','BSH','BSD','BSA','SBH','SBD','SBA'], inplace=True, axis=1)
df10_11.drop(['GBH','GBD','GBA','SJH','SJD','SJA','BSH','BSD','BSA','SBH','SBD','SBA'], inplace=True, axis=1)
df11_12.drop(['GBH','GBD','GBA','SJH','SJD','SJA','BSH','BSD','BSA','SBH','SBD','SBA'], inplace=True, axis=1)
df12_13.drop(['GBH','GBD','GBA','SJH','SJD','SJA','BSH','BSD','BSA','PSCH','PSCD','PSCA','PSH','PSD','PSA'], inplace=True, axis=1)
df13_14.drop(['SJH','SJD','SJA','PSCH','PSCD','PSCA','PSH','PSD','PSA'], inplace=True, axis=1)
df14_15.drop(['SJH','SJD','SJA','PSCH','PSCD','PSCA','PSH','PSD','PSA'], inplace=True, axis=1)

df15_16.drop(['PSCH','PSCD','PSCA','PSH','PSD','PSA'], inplace=True, axis=1)
df16_17.drop(['PSCH','PSCD','PSCA','PSH','PSD','PSA'], inplace=True, axis=1)
df17_18.drop(['PSCH','PSCD','PSCA','PSH','PSD','PSA'], inplace=True, axis=1)
df18_18.drop(['PSCH','PSCD','PSCA','PSH','PSD','PSA'], inplace=True, axis=1)

# %%
columns_dict = {#'04_05': df04_05.columns, 
              '05_06': df05_06.columns,
              '06_07': df06_07.columns,
              '07_08': df07_08.columns,
              '08_09': df08_09.columns,
              '09_10': df09_10.columns,
              '10_11': df10_11.columns,
              '11_12': df11_12.columns,
              '12_13': df12_13.columns,
              '13_14': df13_14.columns,
              '14_15': df14_15.columns,
              '15_16': df15_16.columns,
              '16_17': df16_17.columns,
              '17_18': df17_18.columns,
              '18_18': df18_18.columns}
columns_df = pd.DataFrame.from_dict(columns_dict, orient='index')
columns_df = columns_df.transpose()

# %%
columns_df[:]
# Out:
#        05_06     06_07     07_08     08_09     09_10     10_11     11_12  \
# 0        Div       Div       Div       Div       Div       Div       Div
# 1       Date      Date      Date      Date      Date      Date      Date
# 2   HomeTeam  HomeTeam  HomeTeam  HomeTeam  HomeTeam  HomeTeam  HomeTeam
# 3   AwayTeam  AwayTeam  AwayTeam  AwayTeam  AwayTeam  AwayTeam  AwayTeam
# 4       FTHG      FTHG      FTHG      FTHG      FTHG      FTHG      FTHG
# 5       FTAG      FTAG      FTAG      FTAG      FTAG      FTAG      FTAG
# 6        FTR       FTR       FTR       FTR       FTR       FTR       FTR
# 7       HTHG      HTHG      HTHG      HTHG      HTHG      HTHG      HTHG
# 8       HTAG      HTAG      HTAG      HTAG      HTAG      HTAG      HTAG
# 9        HTR       HTR       HTR       HTR       HTR       HTR       HTR
# 10   Referee   Referee   Referee   Referee   Referee   Referee   Referee
# 11        HS        HS        HS        HS        HS        HS        HS
# ...

# %%
df = pd.concat([df05_06, df06_07, df07_08, df08_09, df09_10, df10_11, df11_12, 
                df12_13, df13_14, df14_15, df15_16, df16_17, df17_18, df18_18])

# %%
df.rename(columns={'BbMx>2.5': 'BbMxM','BbAv>2.5':'BbAvM',
                   'BbMx<2.5':'BbMxL','BbAv<2.5':'BbAvL',}, inplace=True)

# %%
df.columns
# Out:
# Index(['Div', 'Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG',
#        'HTAG', 'HTR', 'Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC',
#        'AC', 'HY', 'AY', 'HR', 'AR', 'B365H', 'B365D', 'B365A', 'BWH', 'BWD',
#        'BWA', 'IWH', 'IWD', 'IWA', 'LBH', 'LBD', 'LBA', 'WHH', 'WHD', 'WHA',
#        'VCH', 'VCD', 'VCA', 'Bb1X2', 'BbMxH', 'BbAvH', 'BbMxD', 'BbAvD',
#        'BbMxA', 'BbAvA', 'BbOU', 'BbMxM', 'BbAvM', 'BbMxL', 'BbAvL', 'BbAH',
#        'BbAHh', 'BbMxAHH', 'BbAvAHH', 'BbMxAHA', 'BbAvAHA'],
#       dtype='object')

# %%
df[['FTHG', 'FTAG', 'FTR', 'HTHG','HTAG', 'HTR', 'Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC','AC', 'HY', 'AY', 'HR', 'AR']]
# Out:
#     FTHG  FTAG FTR  HTHG  HTAG HTR        Referee    HS    AS   HST  AST  \
# 0    2.0   2.0   D   2.0   2.0   D        M Riley   3.0  13.0   2.0  6.0
# 1    0.0   2.0   A   0.0   1.0   A         G Poll  10.0  12.0   5.0  5.0
# 2    0.0   0.0   D   0.0   0.0   D       R Styles  15.0   7.0   7.0  4.0
# 3    0.0   0.0   D   0.0   0.0   D          C Foy  15.0  13.0   8.0  3.0
# 4    0.0   0.0   D   0.0   0.0   D       M Halsey   4.0  16.0   2.0  7.0
# 5    0.0   2.0   A   0.0   1.0   A       B Knight  11.0  11.0   7.0  6.0
# 6    1.0   3.0   A   1.0   1.0   D         H Webb  12.0  14.0   8.0  4.0
# 7    3.0   1.0   H   0.0   1.0   A        A Wiley  13.0  11.0   5.0  5.0
# 8    2.0   0.0   H   0.0   0.0   D      S Bennett  15.0   2.0  12.0  1.0
# 9    0.0   1.0   A   0.0   0.0   D  M Clattenburg  12.0  20.0   5.0  9.0
# 10   1.0   2.0   A   1.0   1.0   D  M Clattenburg   9.0   9.0   2.0  6.0
# 11   2.0   1.0   H   1.0   0.0   H         H Webb  16.0   8.0   9.0  4.0
# ...

# %% [markdown]
# ## Separate the Features from the Labels
# Features are the inputs for the neural net and labels are the ones to be predicted)

# %%
#df.drop(['Country', 'League', 'Date', 'Time', 'HG', 'AG'], axis = 1, inplace = True)

# %%
df.dropna(inplace=True)

# %%
df['FTR'].unique()
# Out:
# array(['D', 'A', 'H'], dtype=object)

# %%
df['FTR'].replace(['H', 'D', 'A'],[1, 0, 2],inplace=True)

# %%
df['HomeTeam'] = df['HomeTeam'].apply(str)
df['AwayTeam'] = df['AwayTeam'].apply(str)
df['Referee'] = df['Referee'].apply(str)

# %%
df.dtypes
# Out:
# Div          object
# Date         object
# HomeTeam     object
# AwayTeam     object
# FTHG        float64
# FTAG        float64
# FTR           int64
# HTHG        float64
# HTAG        float64
# HTR          object
# Referee      object
# HS          float64
# AS          float64
# HST         float64
# AST         float64
# HF          float64
# AF          float64
# HC          float64
# AC          float64
# HY          float64
# AY          float64
# HR          float64
# AR          float64
# B365H       float64
# B365D       float64
# B365A       float64
# BWH         float64
# BWD         float64
# BWA         float64
# IWH         float64
# IWD         float64
# IWA         float64
# LBH         float64
# LBD         float64
# LBA         float64
# WHH         float64
# WHD         float64
# WHA         float64
# VCH         float64
# VCD         float64
# VCA         float64
# Bb1X2       float64
# BbMxH       float64
# BbAvH       float64
# BbMxD       float64
# ...

# %%
x_data = df.drop(['FTR'], axis=1)
y_label = df['FTR']

# %% [markdown]
# ## Extract the test sample from the train data
# ### test_size is the percentage of the data to being used for the tests (normally is 30%)

# %%
X_train, X_test, y_train, y_test = train_test_split(x_data, y_label, test_size = 0.30)

# %% [markdown]
# ## Create the feature columns
# ## Use "tf.feature_column.categorical_column_with_hash_bucket" para features em strings
#    hash_bucket_size é o número de parâmetros possíveis (se a feature em questão for A, B ou C; hash_bucket_size=3)
# ## Use "tf.feature_column.categorical_column_with_identity" para formatos em int
#    num_buckets é o número de parâmetros possíveis (se a feature for 1 até 7, num_buckets=7)

# %%
df.dtypes
# Out:
# Div          object
# Date         object
# HomeTeam     object
# AwayTeam     object
# FTHG        float64
# FTAG        float64
# FTR           int64
# HTHG        float64
# HTAG        float64
# HTR          object
# Referee      object
# HS          float64
# AS          float64
# HST         float64
# AST         float64
# HF          float64
# AF          float64
# HC          float64
# AC          float64
# HY          float64
# AY          float64
# HR          float64
# AR          float64
# B365H       float64
# B365D       float64
# B365A       float64
# BWH         float64
# BWD         float64
# BWA         float64
# IWH         float64
# IWD         float64
# IWA         float64
# LBH         float64
# LBD         float64
# LBA         float64
# WHH         float64
# WHD         float64
# WHA         float64
# VCH         float64
# VCD         float64
# VCA         float64
# Bb1X2       float64
# BbMxH       float64
# BbAvH       float64
# BbMxD       float64
# ...

# %%
HomeTeam = tf.feature_column.categorical_column_with_hash_bucket('HomeTeam',
                                                                 hash_bucket_size = df['HomeTeam'].nunique())
AwayTeam = tf.feature_column.categorical_column_with_hash_bucket('AwayTeam',
                                                                 hash_bucket_size = df['AwayTeam'].nunique())

FTR = tf.feature_column.categorical_column_with_identity('FTR',
                                                         num_buckets = df['FTR'].nunique())

Referee = tf.feature_column.categorical_column_with_hash_bucket('Referee',
                                                                hash_bucket_size = df['Referee'].nunique())

# %% [markdown]
# ## Passar as feature columns categoricas para embedded
# ## Usado para conseguir usar a Dense Neural Net

# %%
HomeTeam = tf.feature_column.embedding_column(HomeTeam, dimension = df['HomeTeam'].nunique())
AwayTeam = tf.feature_column.embedding_column(AwayTeam, dimension = df['AwayTeam'].nunique())

FTR = tf.feature_column.embedding_column(FTR, dimension = df['FTR'].nunique())

Referee = tf.feature_column.embedding_column(Referee, dimension = df['Referee'].nunique())

# %% [markdown]
# ## Criar feature columns numéricas

# %%
#Statistics
#Shots/Target
HS = tf.feature_column.numeric_column('HS')
AS = tf.feature_column.numeric_column('AS')
HST = tf.feature_column.numeric_column('HST')
AST = tf.feature_column.numeric_column('AST')
#Fouls Commited
HF = tf.feature_column.numeric_column('HF')
AF = tf.feature_column.numeric_column('AF')
#Corners
HC = tf.feature_column.numeric_column('HC')
AC = tf.feature_column.numeric_column('AC')
#Yellow and Red Cards
HY = tf.feature_column.numeric_column('HY')
AY = tf.feature_column.numeric_column('AY')
HR = tf.feature_column.numeric_column('HR')
AR = tf.feature_column.numeric_column('AR')

#Odds
B365H = tf.feature_column.numeric_column('B365H')
B365D = tf.feature_column.numeric_column('B365D')
B365A = tf.feature_column.numeric_column('B365A')

BWH = tf.feature_column.numeric_column('BWH')
BWD = tf.feature_column.numeric_column('BWD')
BWA = tf.feature_column.numeric_column('BWA')

IWH = tf.feature_column.numeric_column('IWH')
IWD = tf.feature_column.numeric_column('IWD')
IWA = tf.feature_column.numeric_column('IWA')

LBH = tf.feature_column.numeric_column('LBH')
LBD = tf.feature_column.numeric_column('LBD')
LBA = tf.feature_column.numeric_column('LBA')

WHH = tf.feature_column.numeric_column('WHH')
WHD = tf.feature_column.numeric_column('WHD')
WHA = tf.feature_column.numeric_column('WHA')

VCH = tf.feature_column.numeric_column('VCH')
VCD = tf.feature_column.numeric_column('VCD')
VCA = tf.feature_column.numeric_column('VCA')

Bb1X2 = tf.feature_column.numeric_column('Bb1X2')
BbMxH = tf.feature_column.numeric_column('BbMxH')
BbAvH = tf.feature_column.numeric_column('BbAvH')
BbAvH = tf.feature_column.numeric_column('BbAvH')
BbMxD = tf.feature_column.numeric_column('BbMxD')
BbAvD = tf.feature_column.numeric_column('BbAvD')
BbMxA = tf.feature_column.numeric_column('BbMxA')
BbAvA = tf.feature_column.numeric_column('BbAvA')
BbOU = tf.feature_column.numeric_column('BbOU')
BbMxM = tf.feature_column.numeric_column('BbMxM')
BbAvM = tf.feature_column.numeric_column('BbAvM')
BbMxL = tf.feature_column.numeric_column('BbMxL')
BbAvL = tf.feature_column.numeric_column('BbAvL')
BbAH = tf.feature_column.numeric_column('BbAH')
BbAHh = tf.feature_column.numeric_column('BbAHh')
BbMxAHH = tf.feature_column.numeric_column('BbMxAHH')
BbAvAHH = tf.feature_column.numeric_column('BbAvAHH')
BbMxAHA = tf.feature_column.numeric_column('BbMxAHA')
BbAvAHA = tf.feature_column.numeric_column('BbAvAHA')

# %% [markdown]
# ## Definir feature columns para input

# %%
X_train.columns
# Out:
# Index(['Div', 'Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'HTHG', 'HTAG',
#        'HTR', 'Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC',
#        'HY', 'AY', 'HR', 'AR', 'B365H', 'B365D', 'B365A', 'BWH', 'BWD', 'BWA',
#        'IWH', 'IWD', 'IWA', 'LBH', 'LBD', 'LBA', 'WHH', 'WHD', 'WHA', 'VCH',
#        'VCD', 'VCA', 'Bb1X2', 'BbMxH', 'BbAvH', 'BbMxD', 'BbAvD', 'BbMxA',
#        'BbAvA', 'BbOU', 'BbMxM', 'BbAvM', 'BbMxL', 'BbAvL', 'BbAH', 'BbAHh',
#        'BbMxAHH', 'BbAvAHH', 'BbMxAHA', 'BbAvAHA'],
#       dtype='object')

# %%
feat_cols = [HomeTeam, AwayTeam, Referee, 
             HS, AS, HST, AST, HF, AF, HC, AC,HY, AY, HR, 
             AR, B365H, B365D, B365A, BWH, BWD, BWA, IWH, IWD,
             IWA, LBH, LBD, LBA, WHH, WHD, WHA, VCH, VCD, VCA, 
             Bb1X2, BbMxH, BbAvH, BbMxD, BbAvD, BbMxA, BbAvA, BbOU,
             BbMxM, BbAvM, BbMxL, BbAvL, BbAH, BbAHh, BbMxAHH, 
             BbAvAHH, BbMxAHA, BbAvAHA]

# %% [markdown]
# ## Input para o model
#    batch_size é o número de dados que serão usados em cada passo, shuffle definirá se os dados serão aleatórios em cada passo

# %%
len(df)
# Out:
# 4849

# %%
total_dimension_of_df = len(df) * len(df.columns)
total_dimension_of_df
# Out:
# 286091

# %%
input_func = tf.estimator.inputs.pandas_input_fn(x = X_train, y = y_train,
                                                 batch_size = 100,
                                                 num_epochs = None,
                                                 shuffle = True)

# %% [markdown]
# ## Criação do modelo (O modelo salva automaticamente após ser treinado)
# ## CUIDADO COM O NUMERO DE NEURONIOS, TEM QUE SER IGUAL AO TREINAMENTO!!!!!
#    Se o número de neurônios for alterado, delete o modelo e começe o treinamento de novo
#    O número entre colchetes é o número de neurônios use uma camada apenas, com um número um pouco acima do número de inputs
#    model_dir determina onde o modelo será salvo, se alguma característica da base de dados ou da rede neural for modificada, delete o modelo e reinicie o TREINAMENTO
#     O modelo será salvo a partir da última rodada de treinamento

# %%
len(df.columns)
# Out:
# 59

# %%
model = tf.estimator.DNNClassifier([60, 15, 30, 15, 3],
                                   feature_columns = feat_cols,
                                   n_classes = 3,
                                   model_dir ="./model")
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': './model', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x0000021A17751240>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %% [markdown]
# ## Treinar modelo
#   steps é o número de passos (cada passo utiliza um "batch" ou pacote de dados)

# %%
model.train(input_fn = input_func, steps = 100000)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into ./model\model.ckpt.
# INFO:tensorflow:loss = 128.5827, step = 0
# INFO:tensorflow:global_step/sec: 62.3941
# INFO:tensorflow:loss = 100.02787, step = 100 (1.604 sec)
# INFO:tensorflow:global_step/sec: 78.0291
# INFO:tensorflow:loss = 108.57827, step = 200 (1.282 sec)
# INFO:tensorflow:global_step/sec: 78.5179
# INFO:tensorflow:loss = 104.13437, step = 300 (1.274 sec)
# INFO:tensorflow:global_step/sec: 84.6852
# INFO:tensorflow:loss = 107.39438, step = 400 (1.181 sec)
# INFO:tensorflow:global_step/sec: 79.9581
# INFO:tensorflow:loss = 105.417404, step = 500 (1.250 sec)
# INFO:tensorflow:global_step/sec: 84.9003
# INFO:tensorflow:loss = 106.29273, step = 600 (1.179 sec)
# ...

# %% [markdown]
# ## Evaluation do teste

# %%
eval_func = tf.estimator.inputs.pandas_input_fn(x = X_test, y = y_test,
                                                batch_size = len(X_test),
                                                num_epochs = 1, shuffle = False)

# %% [markdown]
# ## Teste
#  O teste vai determinar a precisão do seu modelo

# %%
results = model.evaluate(eval_func)

# %%
results

# %% [markdown]
# ## Input da previsão

# %%
pred_func = tf.estimator.inputs.pandas_input_fn(x = X_test, batch_size = len(X_test), shuffle = False)

# %% [markdown]
# ## Previsão
# A previsão vai determinar outras características do resultado final do seu modelo

# %%
prediction = model.predict(pred_func)
prediction = list(prediction)

final_preds = [pred['class_ids'][0] for pred in prediction]
print(final_preds)
print(classification_report(y_test, final_preds))

# %% [markdown]
# ### Precision: o algoritmo acertou X das previsões (X/X_true)
# ### Recall: de 'X_true' parametros, o algoritmo acertou X (X/X_true)

# %%
             precision    recall  f1-score   support

          0       0.30      0.12      0.18       400
          1       0.55      0.83      0.66       669
          2       0.55      0.40      0.46       386

avg / total       0.48      0.52      0.47      1455

# %%
import tensorflow as tf

# %%
from tensorflow import keras

# %%
dnn_keras_model = keras.Sequential()

# %%
dnn_keras_model.add(keras.layers.Dense(units=10, input_dim=10, activation='relu'))

# %%
dnn_keras_model.add(keras.layers.Dense(units=10, activation='relu'))
dnn_keras_model.add(keras.layers.Dense(units=10, activation='relu'))

# %%
dnn_keras_model.add(keras.layers.Dense(units=3, activation='softmax'))

# %%
from keras import losses,optimizers,metrics,activations

# %%
dnn_keras_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy',
                        metrics=['accuracy'])

# %%
dnn_keras_model.compile(optimizer=tf.train.RMSPropOptimizer(0.01),
                        loss=keras.losses.categorical_crossentropy,
                        metrics=[keras.metrics.categorical_accuracy])

# %%
df_keras = pd.read_csv('../Data/Brazil_Serie_A/BRA.csv')

# %%
df_keras.tail()

# %%
df_keras.dropna(inplace=True)

# %%
df_keras.drop(['Country', 'League', 'Date', 'Time', 'Home', 'Away'], axis = 1, inplace = True)

# %%
df_keras['Res'].replace(['H', 'D', 'A'],[1, 0, 2], inplace=True)

# %%
x_data_keras = df_keras.drop(['HG', 'AG', 'Res'], axis=1)

# %%
y_label_keras = df_keras[['HG', 'AG', 'Res']]

# %%
X_train_keras, X_test_keras, y_train_keras, y_test_keras = train_test_split(x_data_keras, y_label_keras, test_size = 0.30)

# %%
dnn_keras_model.fit(X_train_keras, y_train_keras, epochs=1000)

# %%
predictions = dnn_keras_model.predict_classes(X_test_keras)

# %%
from sklearn.metrics import classification_report

# %%
y_test_keras.tail()

# %%
y_test_keras['HG'] = y_test_keras['HG'].apply(int)
y_test_keras['AG'] = y_test_keras['AG'].apply(int)
y_test_keras['Res'] = y_test_keras['Res'].apply(int)

# %%
print(classification_report(predictions, y_test_keras))
